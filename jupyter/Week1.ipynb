# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

elite = pd.read_csv('boardgame-elite-users.csv')
frequent = pd.read_csv('boardgame-frequent-users.csv')
titles = pd.read_csv('boardgame-titles.csv')
elite = elite.rename(columns = {'Compiled from boardgamegeek.com by Matt Borthwick':'UserID'})

elite.rating.hist()

# %%
one_game = elite[elite.gameID==68448]
one_game.rating.hist()
